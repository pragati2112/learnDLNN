# %%
import os
import copy
import shutil  
import re 
import time
import calendar

ts = calendar.timegm(time.gmtime())
print(ts)
base_dir = "C:\\Users\\91958\\all_images"

image_dir = "C:\\Users\\91958\\all_images\\images\\"

files = os.listdir(image_dir)

count = 0
for count, file in enumerate(files):
    images = os.listdir(image_dir + file )
    for count1 , img in enumerate(images):
        src = image_dir + file + '/' + img
        dst = str(ts)+str(count)+ str(count1) + '.jpeg'
        dst1 = image_dir + file + '/'+ dst
        print(dst)
        os.rename(src , dst1)
        shutil.copy(dst1 , base_dir + '/eloc_dataset/')
# Out:
# 1590653005
# 159065300500.jpeg
# 159065300501.jpeg
# 159065300502.jpeg
# 159065300503.jpeg
# 159065300510.jpeg
# 159065300511.jpeg
# 159065300512.jpeg
# 159065300513.jpeg
# 159065300520.jpeg
# 159065300521.jpeg
# 159065300522.jpeg
# 159065300523.jpeg
# 159065300524.jpeg
# 159065300530.jpeg
# 159065300531.jpeg
# 159065300532.jpeg
# 159065300533.jpeg
# 159065300534.jpeg
# 159065300540.jpeg
# 159065300541.jpeg
# 159065300542.jpeg
# 159065300543.jpeg
# 159065300544.jpeg
# 159065300550.jpeg
# 159065300551.jpeg
# 159065300552.jpeg
# 159065300553.jpeg
# 159065300560.jpeg
# 159065300561.jpeg
# 159065300562.jpeg
# 159065300563.jpeg
# 159065300564.jpeg
# 159065300570.jpeg
# 159065300580.jpeg
# 159065300581.jpeg
# 159065300582.jpeg
# 159065300583.jpeg
# 159065300584.jpeg
# 159065300590.jpeg
# 159065300591.jpeg
# 159065300592.jpeg
# 159065300593.jpeg
# 1590653005100.jpeg
# 1590653005101.jpeg
# 1590653005102.jpeg
# 1590653005103.jpeg
# 1590653005104.jpeg
# 1590653005110.jpeg
# 1590653005111.jpeg
# ...

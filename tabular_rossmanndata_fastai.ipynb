# %%
from fastai.tabular import *

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import pandas as pd
df_train = pd.read_csv("train.csv")
# Out:
# c:\users\91958\envs\pytorch\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_train.head()
# Out:
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  2015-07-31   5263        555     1      1            0
# 1      2          5  2015-07-31   6064        625     1      1            0
# 2      3          5  2015-07-31   8314        821     1      1            0
# 3      4          5  2015-07-31  13995       1498     1      1            0
# 4      5          5  2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %%
len(df_train)
# Out:
# 1017209

# %%
df_store = pd.read_csv("store.csv")

# %%
df_store.head()
# Out:
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a               1270.0                        9.0
# 1      2         a          a                570.0                       11.0
# 2      3         a          a              14130.0                       12.0
# 3      4         c          c                620.0                        9.0
# 4      5         a          a              29910.0                        4.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                    2008.0       0              NaN              NaN
# 1                    2007.0       1             13.0           2010.0
# 2                    2006.0       1             14.0           2011.0
# 3                    2009.0       0              NaN              NaN
# 4                    2015.0       0              NaN              NaN
#
#      PromoInterval
# 0              NaN
# 1  Jan,Apr,Jul,Oct
# ...

# %%
df_store.isnull().sum()
# Out:
# Store                          0
# StoreType                      0
# Assortment                     0
# CompetitionDistance            3
# CompetitionOpenSinceMonth    354
# CompetitionOpenSinceYear     354
# Promo2                         0
# Promo2SinceWeek              544
# Promo2SinceYear              544
# PromoInterval                544
# dtype: int64

# %%
df_store['CompetitionDistance'].fillna(0)
# Out:
# 0        1270.0
# 1         570.0
# 2       14130.0
# 3         620.0
# 4       29910.0
#          ...
# 1110     1900.0
# 1111     1880.0
# 1112     9260.0
# 1113      870.0
# 1114     5350.0
# Name: CompetitionDistance, Length: 1115, dtype: float64

# %%
df_weather = pd.read_csv('weather.csv')

df_weather.head().T
# Out:
#                                              0                   1  \
# file                        NordrheinWestfalen  NordrheinWestfalen
# Date                                2013-01-01          2013-01-02
# Max_TemperatureC                             8                   7
# Mean_TemperatureC                            4                   4
# Min_TemperatureC                             2                   1
# Dew_PointC                                   7                   5
# MeanDew_PointC                               5                   3
# Min_DewpointC                                1                   2
# Max_Humidity                                94                  93
# Mean_Humidity                               87                  85
# Min_Humidity                                65                  78
# Max_Sea_Level_PressurehPa                 1013                1028
# Mean_Sea_Level_PressurehPa                1005                1022
# ...

# %%
df_store_states = pd.read_csv('store_states.csv')

df_store_states.head()
# Out:
#    Store State
# 0      1    HE
# 1      2    TH
# 2      3    NW
# 3      4    BE
# 4      5    SN

# %%
df_merge = pd.merge(df_store, df_store_states, on='Store', how='inner')

# %%
df_merge.head()
# Out:
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a               1270.0                        9.0
# 1      2         a          a                570.0                       11.0
# 2      3         a          a              14130.0                       12.0
# 3      4         c          c                620.0                        9.0
# 4      5         a          a              29910.0                        4.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                    2008.0       0              NaN              NaN
# 1                    2007.0       1             13.0           2010.0
# 2                    2006.0       1             14.0           2011.0
# 3                    2009.0       0              NaN              NaN
# 4                    2015.0       0              NaN              NaN
#
#      PromoInterval State
# 0              NaN    HE
# ...

# %%
df_merge2 = pd.merge(df_train, df_merge, on='Store', how='inner')

# %%
df_merge2.head().T
# Out:
#                                     0           1           2           3  \
# Store                               1           1           1           1
# DayOfWeek                           5           4           3           2
# Date                       2015-07-31  2015-07-30  2015-07-29  2015-07-28
# Sales                            5263        5020        4782        5011
# Customers                         555         546         523         560
# Open                                1           1           1           1
# Promo                               1           1           1           1
# StateHoliday                        0           0           0           0
# SchoolHoliday                       1           1           1           1
# StoreType                           c           c           c           c
# Assortment                          a           a           a           a
# CompetitionDistance              1270        1270        1270        1270
# ...

# %%
len(df_merge2)
# Out:
# 1017209

# %%
df_state_names = pd.read_csv('state_names.csv')

df_state_names.head(17)
# Out:
#                 StateName  State
# 0       BadenWuerttemberg     BW
# 1                  Bayern     BY
# 2                  Berlin     BE
# 3             Brandenburg     BB
# 4                  Bremen     HB
# 5                 Hamburg     HH
# 6                  Hessen     HE
# 7   MecklenburgVorpommern     MV
# 8           Niedersachsen  HB,NI
# 9      NordrheinWestfalen     NW
# 10         RheinlandPfalz     RP
# 11               Saarland     SL
# 12                Sachsen     SN
# 13          SachsenAnhalt     ST
# 14      SchleswigHolstein     SH
# 15             Thueringen     TH

# %%
len(df_state_names)
# Out:
# 16

# %%
df_merge3 = pd.merge(df_state_names, df_merge2, on='State', how='inner')

# %%
df_merge3.head().T
# Out:
#                                            0                  1  \
# StateName                  BadenWuerttemberg  BadenWuerttemberg
# State                                     BW                 BW
# Store                                     16                 16
# DayOfWeek                                  5                  4
# Date                              2015-07-31         2015-07-30
# Sales                                  10231              10226
# Customers                                979                953
# Open                                       1                  1
# Promo                                      1                  1
# StateHoliday                               0                  0
# SchoolHoliday                              1                  1
# StoreType                                  a                  a
# Assortment                                 c                  c
# CompetitionDistance                     3270               3270
# ...

# %%
len(df_merge3)
# Out:
# 1017209

# %%
df_googletrend = pd.read_csv('googletrend.csv')

df_googletrend.head()
# Out:
#              file                     week  trend
# 0  Rossmann_DE_SN  2012-12-02 - 2012-12-08     96
# 1  Rossmann_DE_SN  2012-12-09 - 2012-12-15     95
# 2  Rossmann_DE_SN  2012-12-16 - 2012-12-22     91
# 3  Rossmann_DE_SN  2012-12-23 - 2012-12-29     48
# 4  Rossmann_DE_SN  2012-12-30 - 2013-01-05     67

# %%
len(df_googletrend)
# Out:
# 2072

# %%
len(df_weather)
# Out:
# 15840

# %%
df_weather.head()
# Out:
#                  file        Date  Max_TemperatureC  Mean_TemperatureC  \
# 0  NordrheinWestfalen  2013-01-01                 8                  4
# 1  NordrheinWestfalen  2013-01-02                 7                  4
# 2  NordrheinWestfalen  2013-01-03                11                  8
# 3  NordrheinWestfalen  2013-01-04                 9                  9
# 4  NordrheinWestfalen  2013-01-05                 8                  8
#
#    Min_TemperatureC  Dew_PointC  MeanDew_PointC  Min_DewpointC  Max_Humidity  \
# 0                 2           7               5              1            94
# 1                 1           5               3              2            93
# 2                 6          10               8              4           100
# 3                 8           9               9              8           100
# 4                 7           8               7              6           100
#
# ...

# %%
df_weather_trend = df_weather.merge(df_googletrend,how='left')

# %%
df_weather_trend.head().T
# Out:
#                                              0                   1  \
# file                        NordrheinWestfalen  NordrheinWestfalen
# Date                                2013-01-01          2013-01-02
# Max_TemperatureC                             8                   7
# Mean_TemperatureC                            4                   4
# Min_TemperatureC                             2                   1
# Dew_PointC                                   7                   5
# MeanDew_PointC                               5                   3
# Min_DewpointC                                1                   2
# Max_Humidity                                94                  93
# Mean_Humidity                               87                  85
# Min_Humidity                                65                  78
# Max_Sea_Level_PressurehPa                 1013                1028
# Mean_Sea_Level_PressurehPa                1005                1022
# ...

# %%
df_merge4 = pd.merge(df_weather_trend, df_merge3, on='Date', how='inner')

# %%
df_merge4.head().T
# Out:
#                                              0                   1  \
# file                        NordrheinWestfalen  NordrheinWestfalen
# Date                                2013-01-01          2013-01-01
# Max_TemperatureC                             8                   8
# Mean_TemperatureC                            4                   4
# Min_TemperatureC                             2                   2
# Dew_PointC                                   7                   7
# MeanDew_PointC                               5                   5
# Min_DewpointC                                1                   1
# Max_Humidity                                94                  94
# Mean_Humidity                               87                  87
# Min_Humidity                                65                  65
# Max_Sea_Level_PressurehPa                 1013                1013
# Mean_Sea_Level_PressurehPa                1005                1005
# ...

# %%
len(df_merge4)
# Out:
# 16275344

# %%
from fastai.basics import *

# %%
cat_vars = ['Store', 'DayOfWeek', 'StateHoliday', 'CompetitionMonthsOpen',
    'Promo2Weeks', 'StoreType', 'Assortment', 'PromoInterval', 'CompetitionOpenSinceYear', 'Promo2SinceYear',
    'State', 'Week', 'Events', 'Promo2', 'SchoolHoliday']

cont_vars = ['CompetitionDistance', 'Max_TemperatureC', 'Mean_TemperatureC', 'Min_TemperatureC',
   'Max_Humidity', 'Mean_Humidity', 'Min_Humidity', 'Max_Wind_SpeedKm_h', 
   'Mean_Wind_SpeedKm_h', 'CloudCover', 'trend', 'trend_DE', 'Promo' ]

# %%
path = 'C://Users//91958//Rosmann_fastai//'
procs=[FillMissing, Categorify, Normalize]
data = (TabularList.from_df(df_merge4, path=path, cat_names=cat_vars, cont_names=cont_vars, procs=procs)
                .split_from_df()
                .label_from_df(cols='Sales', label_cls=FloatList, log=True)
                .databunch())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-68-31c3f86a4de3> in <module>
#       1 path = 'C://Users//91958//Rosmann_fastai//'
# ----> 2 procs=[FillMissing, Categorify, Normalize]
#       3 data = (TabularList.from_df(df_merge4, path=path, cat_names=cat_vars, cont_names=cont_vars, procs=procs,)
#       4                 .split_from_df()
#       5                 .label_from_df(cols='Sales', label_cls=FloatList, log=True)
#
# NameError: name 'FillMissing' is not defined

# %%
tfm = FillMissing(cat_names, cont_names)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-72-cfa8be9ab420> in <module>
# ----> 1 tfm = FillMissing(cat_names, cont_names)
#
# NameError: name 'FillMissing' is not defined

# %%
from fastai import *
